# %%
import json
from alt_setup_creator_new import AltSetupHandler

# %%
# TODO: load this from a config?
# conf = {
# "SM": {
#     "g1z": 1.,
#     "ka": 1.,
#     "la": 0.,
# },
# "variations": {
#     "g1z": [1.e-1, 5e-2, 2e-2, 1e-2, 5e-3, 2e-3, 1e-3, 5e-4, 2e-4, 1e-4, 5e-5, 2e-5, 1e-5],
#     "ka": [1.e-1, 5e-2, 2e-2, 1e-2, 5e-3, 2e-3, 1e-3, 5e-4, 2e-4, 1e-4, 5e-5, 2e-5, 1e-5],
#     "la": [1.e-1, 5e-2, 2e-2, 1e-2, 5e-3, 2e-3, 1e-3, 5e-4, 2e-4, 1e-4, 5e-5, 2e-5, 1e-5],
# },
# }
# with open("alt-configs.json", "w") as f:
#     json.dump(conf, f, indent=2)

# %%
alt_setup_handler = AltSetupHandler("alt-configs-new.json", mirror=True)
alt_configs = alt_setup_handler.get_alt_setup()

# %%
print(json.dumps(alt_configs, indent=2))
# Out:
# {
#   "g1z_pos_1em01": {
#     "g1z": 1.1,
#     "ka": 1.0,
#     "la": 0.0
#   },
#   "g1z_neg_1em01": {
#     "g1z": 0.9,
#     "ka": 1.0,
#     "la": 0.0
#   },
#   "ka_pos_1em01": {
#     "g1z": 1.0,
#     "ka": 1.1,
#     "la": 0.0
#   },
#   "ka_neg_1em01": {
#     "g1z": 1.0,
#     "ka": 0.9,
#     "la": 0.0
#   },
#   "la_pos_1em01": {
#     "g1z": 1.0,
#     "ka": 1.0,
#     "la": 0.1
#   },
#   "la_neg_1em01": {
#     "g1z": 1.0,
#     "ka": 1.0,
#     "la": -0.1
#   },
#   "g1z_pos_1em01_ka_pos_1em01": {
#     "g1z": 1.1,
#     "ka": 1.1,
#     "la": 0.0
#   },
#   "g1z_pos_1em01_ka_neg_1em01": {
#     "g1z": 1.1,
#     "ka": 0.9,
#     "la": 0.0
#   },
#   "g1z_neg_1em01_ka_pos_1em01": {
#     "g1z": 0.9,
#     "ka": 1.1,
#     "la": 0.0
#   },
#   "g1z_neg_1em01_ka_neg_1em01": {
#     "g1z": 0.9,
#     "ka": 0.9,
#     "la": 0.0
#   },
#   "g1z_pos_1em01_la_pos_1em01": {
#     "g1z": 1.1,
#     "ka": 1.0,
#     "la": 0.1
#   },
#   "g1z_pos_1em01_la_neg_1em01": {
# ...
